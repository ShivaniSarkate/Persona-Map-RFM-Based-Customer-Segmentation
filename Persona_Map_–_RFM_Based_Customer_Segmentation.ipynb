# %% [markdown]
# **Project Title : PersonaMap - RFM-Based Customer Segmentation**

# %% [markdown]
# **Objective** : Segment customers using Recency, Frequency, and Monetary (RFM) metrics and identify actionable personas for targeted marketing.

# %% [markdown]
# **Business Context** : A retail brand wants to personalize its outreach. By clustering customers based on RFM behavior, the company can tailor campaigns to high-value, loyal, or at-risk segments.

# %% [markdown]
# **Workflow Overview** :
# - Simulate customer transaction data
# - Calculate RFM scores
# - Scale and reduce dimensions
# - Apply K-means clustering
# - Visualize clusters
# - Map segments to personas
# - Recommend targeting strategies

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Simulate transaction data
np.random.seed(42)
n = 300
df = pd.DataFrame({
    'CustomerID': np.arange(1, n+1),
    'Recency': np.random.randint(1, 365, n),
    'Frequency': np.random.poisson(10, n),
    'Monetary': np.random.normal(500, 150, n)
})

# Step 3: Scale features
scaler = StandardScaler()
scaled = scaler.fit_transform(df[['Recency', 'Frequency', 'Monetary']])

# Step 4: PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled)

# Step 5: K-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
df['Segment'] = kmeans.fit_predict(pca_data)

# Step 6: Visualize clusters
plt.figure(figsize=(8,6))
sns.scatterplot(x=pca_data[:,0], y=pca_data[:,1], hue=df['Segment'], palette='Set2', s=80)
plt.title('Customer Segments via RFM + K-Means')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Executive Summary** :
# | Segment | Traits | Persona | Strategy |
# |--------|--------|---------|----------|
# | 0 | High frequency, high spend | Loyalist | Exclusive rewards, early access |
# | 1 | Low recency, low frequency | Dormant | Re-engagement campaigns |
# | 2 | High recency, moderate spend | Newcomer | Welcome offers, onboarding |
# | 3 | High spend, low frequency | Premium Casual | Upsell bundles, seasonal targeting |
#
# **📌 Recommendation**: Use personas to personalize email campaigns, loyalty programs, and ad targeting.### 📊 Executive Summary
# | Segment | Traits | Persona | Strategy |
# |--------|--------|---------|----------|
# | 0 | High frequency, high spend | Loyalist | Exclusive rewards, early access |
# | 1 | Low recency, low frequency | Dormant | Re-engagement campaigns |
# | 2 | High recency, moderate spend | Newcomer | Welcome offers, onboarding |
# | 3 | High spend, low frequency | Premium Casual | Upsell bundles, seasonal targeting |
#
# **📌 Recommendation**: Use personas to personalize email campaigns, loyalty programs, and ad targeting.
